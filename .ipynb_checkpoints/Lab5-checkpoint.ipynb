# %%
#Импорт библиотек(все уже есть в анаконде) 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
# %matplotlib inline
sns.set(color_codes=True)

# %%
#Задание 1 
#Чтение csv-файла в датафрейм(таблица)
df=pd.read_csv('csv/methane.csv')
emismax=df.sort_values('emissions',ascending=False).loc[:,['country','emissions']].groupby('country').mean().sort_values('emissions',ascending=False).head(10)
emismin=df.sort_values('emissions',ascending=True).loc[:,['country','emissions']].groupby('country').mean().sort_values('emissions',ascending=True).head(10)
#fig, ax = plt.subplots()
#ax.pie(emismax.emissions, labels=emismax.index.values.tolist(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25fca11d930>,
# ...
#  [Text(-0.39489137752671133, 1.026674631981845, 'World'),
#   Text(-0.5273896289041284, -0.9653290523569493, 'China'),
#   Text(0.0318348533529693, -1.0995392408240805, 'United States'),
#   Text(0.41783044121762486, -1.0175547761137407, 'Russia'),
#   Text(0.7051221754106022, -0.8442764462806127, 'India'),
#   Text(0.8808403903067183, -0.6588779908331345, 'Brazil'),
#   Text(0.9822029269301059, -0.49525489430184666, 'Indonesia'),
#   Text(1.047140894712538, -0.3368915947610237, 'European Union'),
#   Text(1.084208151828199, -0.18572205983480078, 'Other'),
#   Text(1.0985344494654876, -0.05676322169819195, 'Iran')],
#  [Text(-0.2153952968327516, 0.5600043447173698, '61.7%'),
#   Text(-0.28766707031134275, -0.5265431194674268, '10.7%'),
#   Text(0.017364465465255982, -0.5997486768131347, '6.1%'),
#   Text(0.22790751339143173, -0.5550298778802222, '5.4%'),
#   Text(0.38461209567851024, -0.46051442524397046, '4.4%'),
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = emismax.index.values.tolist()
data = emismax.emissions
ingredients = emismax.index.values.tolist()


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} g)"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()
