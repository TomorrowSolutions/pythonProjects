# %% [markdown]
# Pandas заметки

# %%
#Импорт библиотек(все уже есть в анаконде) 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
sns.set(color_codes=True)

# %%
#Чтение csv-файла в датафрейм(таблица)
stocks=pd.read_csv('csv/akcii.csv')
stocks=stocks[stocks.Volume>0]
stocks['Date']=pd.to_datetime(stocks['Date'])
# Data for plotting

#fig, ax = plt.subplots()
#plt.plot(eight['Date'],eight['Volume'])

#ax.set(xlabel='year', ylabel='volume',
#       title='About as simple as it gets, folks')
#ax.grid()

#fig.savefig("test.png")
#plt.show()

# %%
#Типы данных
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17827 entries, 5496 to 23322
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       17827 non-null  datetime64[ns]
#  1   Open       17827 non-null  float64
#  2   High       17827 non-null  float64
#  3   Low        17827 non-null  float64
#  4   Close      17827 non-null  float64
#  5   Adj Close  17827 non-null  float64
#  6   Volume     17827 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 1.1 MB

# %%
#Анализ датафрейма
#mean = ср. арифм; std = Среднеквадратическое отклонение ; freq = см unique
#stocks.describe(include='all')

#Гистограмма: по y колво записей, по х значение(особо большие числа в экспоненциальной записи)
stocks.hist(figsize=(10,10))
#Приведение столбца к типу данных(datetime)
stocks['Date']=pd.to_datetime(stocks['Date'])
#stocks.info()
#stocks.head(20)

# %%
#Изменение
#Удаление столбца (ставить axis в 1 иначе не видит + после удаления закомментить тк он ее уже удалил и не может снова)
#stocks=stocks.drop('Adj Close',axis=1)
#stocks.columns

#переименование
#stocks=stocks.rename(columns={'Data':'Date'})
#stocks.columns

#дубликаты
#dubles=stocks[stocks.duplicated]
#их удаление
#dubles = dubles.drop_duplicates()
